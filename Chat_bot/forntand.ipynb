# %%
import streamlit as st


with st.chat_message("user"):
    st.text("hi")

with st.chat_message("assistant"):
    st.text("how can you help me")


user_input  = st.chat_input("Type your message here")
if user_input:
    with st.chat_message("user"):
        st.text(user_input)
# Out:
# 2025-12-23 15:40:50.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.665 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.671 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.675 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.684 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.692 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.695 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.699 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.701 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.708 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.713 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.717 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-12-23 15:40:50.723 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
